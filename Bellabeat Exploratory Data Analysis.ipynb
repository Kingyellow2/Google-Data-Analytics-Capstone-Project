# %% [markdown]
# # INTRODUCTION

# %% [markdown]
# This case study is the Capstone Project of "Google Data Analytics Professional Certificate". The six steps of Data Analysis (Ask,Prepare,Process,Analyze,Share and Act) are used to present this analysis.

# %% [markdown]
# Title: Bellabeat Case Study

# %% [markdown]
# Author: Abdulmalik Abdulmojeed

# %% [markdown]
# Date: 12 September 2022

# %% [markdown]
# ### Bellabeat: How Can A Wellness Technology Company Play It Smart?

# %% [markdown]
# # STEP 1: ASK

# %% [markdown]
# #### 1.0 Background
# Bellabeat is a high-tech manufacturer of beautifully-designed health-focused smart products for women since 2013. Inspiring and empowering women with knowledge about their own health and habits, Bellabeat has grown rapidly and quickly positioned itself as a tech-driven wellness company for females.

# %% [markdown]
# The co-founder and Chief Creative officer, Urska Srsen is confident that an analysis of non-Bellabeat consumer data (ie. FitBit fitness tracker usage data) would reveal more opportunities for growth.

# %% [markdown]
# #### 1.2 Business Task:
# Analyze FitBit Fitness Tracker Data to gain insights into how customers are using the FitBit app and discover trends and insights for Bellabeat marketing strategy.

# %% [markdown]
# #### 1.3 Business Objectives:
# 1. What are the trends identified?
# 2. How could these trends apply to Bellabeat customers?
# 3. How could these trends help influence Bellabeat marketing strategy?

# %% [markdown]
# #### 1.4 Deliverables:
# 1. A clear summary of the Business task
# 2. A description of all data sources used
# 3. Documentation of any cleaning or manipulation of data
# 4. A summary of analysis
# 5. Supporting visualizations and key findings
# 6. High-level content recommendations based on the analysis

# %% [markdown]
# #### 1.5 Key Stakeholders:
# 1. Urška Sršen: Bellabeat’s cofounder and Chief Creative Officer
# 2. Sando Mur: Mathematician, Bellabeat’s cofounder and key member of the Bellabeat executive team
# 3. Bellabeat marketing analytics team: A team of data analysts guiding Bellabeat's marketing strategy.

# %% [markdown]
# # STEP 2: PREPARE

# %% [markdown]
# #### 2.1 Information on Data Source:
# According to its source, the dataset was generated by respondents to a distributed survey via Amazon Mechanical Turk and comprehends dates between 03-12-2016 and 05-12-2016. Thirty FitBit users consented to the submission of their personal tracker data – which includes a minute-level output for physical activity, heart rate, and sleep monitoring. Variation between output represents the use of different types of Fitbit trackers and individual tracking behaviors/preferences.
#
# This public dataset is comprised of 18 CSV files – each containing specific tracking information, such as daily calories, daily steps, etc. The data is organized in the long format, where an Id column identifies each user, and the remaining columns contain different attributes about the said user.
#
# In regard to data bias, considering that the dataset only gathers information of 33 FitBit users over the span of two months, it is important to keep in mind that there is a real possibility that the data isn’t a perfect representation of all FitBit users. However, we can still analyze the dataset and learn interesting information about the surveyed users and how they used their smart tracking devices over that time period.

# %% [markdown]
# #### 2.3 Is the Dataset ROCCC?
# A good data source is ROCCC which stands for Reliable, Original, Comprehensive, Current, and Cited.
# 1. Reliable - The dataset is not reliable as it only has 30 respondents
# 2. Original - The datasets are third party information from public domain by Mobius, not originally by the service provider, Amazon Mechanical Turk. Hence, the originality of the datasets are low.
# 3. Comprehensive - MED - Parameters match most of Bellabeat's products' parameters
# 4. Current - These datasets were generated by respondents to a distributed survey via Amazon Mechanical Turk between 03/12/2016 to 05/12/2016.Data is 5 years old and is not relevant
# 5. Cited - LOW - Data collected from third party, hence unknown

# %% [markdown]
# Overall, the dataset is considered bad quality data and it is not recommended to produce business recommendations based on this data.

# %% [markdown]
# #### 2.4 Data Selection:
# The following file is selected and copied for analysis.
#
#      - DailyActivity_merged.csv

# %% [markdown]
# # STEP 3: PROCESS

# %% [markdown]
# Python Programming Language will be used to prepare and process the dataset.

# %% [markdown]
# #### 3.1 Preparing the Environment
# The numpy, pandas, matplotlib, datetime packages are installed and aliased for easy reading.

# %%
#import packages
import numpy as np      # data arrays
import pandas as pd     #data structure and data analysis
import matplotlib.pyplot as plt   #data visualization
import datetime as dt #    #date time

# %% [markdown]
# #### 3.2 Importing dataset

# %% [markdown]
# Reading in the selected file (DailyActivity_merged.csv).

# %%
# The read_csv function will be used to read the required csv file.
daily_activity = pd.read_csv("Fitabase Data 4.12.16-5.12.16/DailyActivity_merged.csv")

# %% [markdown]
# #### 3.3 Data Cleaning and Manipulation
# steps:
#    1. Observe and familiarize with the dataset
#    2. Check for NAN or missing values
#    3. Peform sanity check of data

# %% [markdown]
# ###### Step1: Preview the dataset using the "head" function to show the first 10 rows of daily_activity to familiarize with the dataset.

# %%
#preview the first 10 rows with the columns
daily_activity.head(10)
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    4/12/2016       13162           8.50             8.50
# 1  1503960366    4/13/2016       10735           6.97             6.97
# 2  1503960366    4/14/2016       10460           6.74             6.74
# 3  1503960366    4/15/2016        9762           6.28             6.28
# 4  1503960366    4/16/2016       12669           8.16             8.16
# 5  1503960366    4/17/2016        9705           6.48             6.48
# 6  1503960366    4/18/2016       13019           8.59             8.59
# 7  1503960366    4/19/2016       15506           9.88             9.88
# 8  1503960366    4/20/2016       10544           6.68             6.68
# 9  1503960366    4/21/2016        9819           6.34             6.34
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                1.88                      0.55
# ...

# %% [markdown]
# ###### Step 2: Find out whether there is any NAN or missing values in the dataset.

# %%
#obtain the number of missing data points per column in the dataset.
missing_values_count = daily_activity.isnull().sum()

#look at the number of missing points in all columns
missing_values_count
# Out:
# Id                          0
# ActivityDate                0
# TotalSteps                  0
# TotalDistance               0
# TrackerDistance             0
# LoggedActivitiesDistance    0
# VeryActiveDistance          0
# ModeratelyActiveDistance    0
# LightActiveDistance         0
# SedentaryActiveDistance     0
# VeryActiveMinutes           0
# FairlyActiveMinutes         0
# LightlyActiveMinutes        0
# SedentaryMinutes            0
# Calories                    0
# dtype: int64

# %% [markdown]
# ###### Step3: Find out the basic information of the dataset
#   - Number of rows and columns.
#   - Column names.
#   - The datatype of values in each column.
#   -  check the unique ID to confirm whether the dataset has 30 IDs.

# %%
#Show the basic information of the dataset
daily_activity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        940 non-null    int64
#  1   ActivityDate              940 non-null    object
#  2   TotalSteps                940 non-null    int64
#  3   TotalDistance             940 non-null    float64
#  4   TrackerDistance           940 non-null    float64
#  5   LoggedActivitiesDistance  940 non-null    float64
#  6   VeryActiveDistance        940 non-null    float64
#  7   ModeratelyActiveDistance  940 non-null    float64
#  8   LightActiveDistance       940 non-null    float64
#  9   SedentaryActiveDistance   940 non-null    float64
#  10  VeryActiveMinutes         940 non-null    int64
#  11  FairlyActiveMinutes       940 non-null    int64
#  12  LightlyActiveMinutes      940 non-null    int64
# ...

# %%
#count the distinct values of 'ID'
unique_id = len(pd.unique(daily_activity['Id']))
print('Number of unique Id:' + str(unique_id))
# Out:
# Number of unique Id:33

# %% [markdown]
# ##### From the above observation, below are the info derived from it:
# - The Dataframe has 15 columns and 940 rows
# - The 'ActivityDate' column is wrongly classified as object 'datatype' instead of 'date time'
# - There are 33 unique IDs, instead of 30 unique Ids as expected from 30 fitness tracker users.
# - There's no NAN or missing values in the dataset.

# %% [markdown]
# ##### The following data manipulation will be performed:
#  1. Convert 'ActivityDate' to 'datetime64' datatype
#  2. convert the 'ActivityDate' format to yyyy-mm-dd.
#  3. Create new column 'DayofTheWeek' by seperating the date into day of the week for further analysis
#  4. Re-arrange and rename columns.
#  5. Create new column 'TotalMins' being the sum of 'FairlyActiveMinutes,LightlyActiveMinutes and SedentaryMinutes'.
#  6. Create new column 'TotalHours' by converting new column in 'number 4' to number of hours.

# %% [markdown]
# ##### Step 1 & 2: Convert 'ActivityDate' from 'object' datatype to 'datetime64' datatype then convert the 'ActivityDate' format to yyyy-mm-dd. Print the head to confirm whether it has been updated to 'datetime64' datatype and dates to yyyy-mm-dd.

# %%
#Convert "ActivtiyDate" to datetime64 datatype and format yyyy-mm-dd
daily_activity["ActivityDate"] = pd.to_datetime(daily_activity["ActivityDate"], format="%m/%d/%Y")

#re-print informaton to confirm
daily_activity.info()

#print the first five rows of 'ActivityDate' to confirm 
daily_activity["ActivityDate"].head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        940 non-null    int64
#  1   ActivityDate              940 non-null    datetime64[ns]
#  2   TotalSteps                940 non-null    int64
#  3   TotalDistance             940 non-null    float64
#  4   TrackerDistance           940 non-null    float64
#  5   LoggedActivitiesDistance  940 non-null    float64
#  6   VeryActiveDistance        940 non-null    float64
#  7   ModeratelyActiveDistance  940 non-null    float64
#  8   LightActiveDistance       940 non-null    float64
#  9   SedentaryActiveDistance   940 non-null    float64
#  10  VeryActiveMinutes         940 non-null    int64
#  11  FairlyActiveMinutes       940 non-null    int64
#  12  LightlyActiveMinutes      940 non-null    int64
# ...

# %% [markdown]
# ##### Create new list with re-arranged column names and re-naming 'daily-activity' to a shorter variable name 'df_activity'.

# %%
#Create new list of re-arranged columns
new_cols = ['Id','ActivityDate','DayofTheWeek','TotalSteps','TotalDistance','TrackerDistance','LoggedActivitiesDistance','VeryActiveDistance','ModeratelyActiveDistance','LightActiveDistance','SedentaryActiveDistance','VeryActiveMinutes','FairlyActiveMinutes','LightlyActiveMinutes','SedentaryMinutes','TotalExerciseMinutes','TotalExerciseHours','Calories']

#reindex functin will be used to rearrange columns based on 'new_cols'
df_activity = daily_activity.reindex(columns=new_cols)

#print first 5 rows to confirm 
df_activity.head(5)
# Out:
#            Id ActivityDate  DayofTheWeek  TotalSteps  TotalDistance  \
# 0  1503960366   2016-04-12           NaN       13162           8.50
# 1  1503960366   2016-04-13           NaN       10735           6.97
# 2  1503960366   2016-04-14           NaN       10460           6.74
# 3  1503960366   2016-04-15           NaN        9762           6.28
# 4  1503960366   2016-04-16           NaN       12669           8.16
#
#    TrackerDistance  LoggedActivitiesDistance  VeryActiveDistance  \
# 0             8.50                       0.0                1.88
# 1             6.97                       0.0                1.57
# 2             6.74                       0.0                2.44
# 3             6.28                       0.0                2.14
# 4             8.16                       0.0                2.71
#
#    ModeratelyActiveDistance  LightActiveDistance  SedentaryActiveDistance  \
# 0                      0.55                 6.06                      0.0
# ...

# %% [markdown]
# ##### step 3: Creating new column by separating the date into day of the week for further analysis.

# %%
#create new column 'day_of_the_week' to represent day of the week
df_activity["DayofTheWeek"] = df_activity["ActivityDate"].dt.day_name()
df_activity["DayofTheWeek"].head(5)
# Out:
# 0      Tuesday
# 1    Wednesday
# 2     Thursday
# 3       Friday
# 4     Saturday
# Name: DayofTheWeek, dtype: object

# %% [markdown]
# ##### Step 4: Rearranging and renaming columns from XxxYyy to xxx_yyy

# %%
#rename columns
df_activity.rename(columns = {"Id" : "id","ActivityDate" : "date","DayofTheWeek" : "day_of_the_week","TotalSteps" : "total_steps","TotalDistance" : "total_dist","TrackerDistance" : "tracker_dist","LoggedActivitiesDistance" : "logged_dist","VeryActiveDistance" : "very_active_dist","ModeratelyActiveDistance" : "moderate_active_dist","LightActiveDistance" : "light_active_dist","SedentaryActiveDistance" : "sedentary_active_dist","VeryActiveMinutes" : "very_active_mins","FairlyActiveMinutes" : "fairly_active_mins","LightlyActiveMinutes" : "lightly_active_mins","SedentaryMinutes" : "sedentary_mins","TotalExerciseMinutes":"total_mins","TotalExerciseHours":"total_hours", "Calories":"calories"}, inplace = True)

#print column names to confirm
print(df_activity.columns.values)
df_activity.head(5)
# Out:
# ['id' 'date' 'day_of_the_week' 'total_steps' 'total_dist' 'tracker_dist'
#  'logged_dist' 'very_active_dist' 'moderate_active_dist'
#  'light_active_dist' 'sedentary_active_dist' 'very_active_mins'
#  'fairly_active_mins' 'lightly_active_mins' 'sedentary_mins' 'total_mins'
#  'total_hours' 'calories']
#            id       date day_of_the_week  total_steps  total_dist  \
# 0  1503960366 2016-04-12         Tuesday        13162        8.50
# 1  1503960366 2016-04-13       Wednesday        10735        6.97
# 2  1503960366 2016-04-14        Thursday        10460        6.74
# 3  1503960366 2016-04-15          Friday         9762        6.28
# 4  1503960366 2016-04-16        Saturday        12669        8.16
#
#    tracker_dist  logged_dist  very_active_dist  moderate_active_dist  \
# 0          8.50          0.0              1.88                  0.55
# 1          6.97          0.0              1.57                  0.69
# ...

# %% [markdown]
# #### Step 5: Creating new column total_mins being the sum of total time logged.

# %%
#create new column "total_mins" containing sum of total minutes.
df_activity["total_mins"] = df_activity["very_active_mins"] + df_activity["fairly_active_mins"] + df_activity["lightly_active_mins"] + df_activity["sedentary_mins"]
df_activity["total_mins"].head(5)
# Out:
# 0    1094
# 1    1033
# 2    1440
# 3     998
# 4    1040
# Name: total_mins, dtype: int64

# %% [markdown]
# ##### Step 6: Creating new column by converting total_mins to number of hours.

# %%
#create new column 'total_hours' by converting to hour and round float to two decimal places
df_activity["total_hours"]= round(df_activity["total_mins"]/60)

#print the first 5 rows to confirm
df_activity["total_hours"].head(5)
# Out:
# 0    18.0
# 1    17.0
# 2    24.0
# 3    17.0
# 4    17.0
# Name: total_hours, dtype: float64

# %% [markdown]
# ###### Data cleaning and manipulation is completed. Hence, data is now ready to be analysed.

# %% [markdown]
# # STEP 4: ANALYZE

# %% [markdown]
# #### 4.1 Perform calculations
# Pulling the statistics of df_activity for analysis:
#
# - count - no. of rows
# - mean (average)
# - std (standard deviation)
# - min and max
# - percentiles 25%, 50%, 75%

# %%
#pull general statistics
df_activity.describe()
# Out:
#                  id   total_steps  total_dist  tracker_dist  logged_dist  \
# count  9.400000e+02    940.000000  940.000000    940.000000   940.000000
# mean   4.855407e+09   7637.910638    5.489702      5.475351     0.108171
# std    2.424805e+09   5087.150742    3.924606      3.907276     0.619897
# min    1.503960e+09      0.000000    0.000000      0.000000     0.000000
# 25%    2.320127e+09   3789.750000    2.620000      2.620000     0.000000
# 50%    4.445115e+09   7405.500000    5.245000      5.245000     0.000000
# 75%    6.962181e+09  10727.000000    7.712500      7.710000     0.000000
# max    8.877689e+09  36019.000000   28.030001     28.030001     4.942142
#
#        very_active_dist  moderate_active_dist  light_active_dist  \
# count        940.000000            940.000000         940.000000
# mean           1.502681              0.567543           3.340819
# std            2.658941              0.883580           2.040655
# ...

# %% [markdown]
# ##### interpreting statistical findings:
# 1. The majority are the sedentary users logging on average minutes of 991 equivalent to 20hours which makes up 81% of the total aveage minutes.
# 2. The average calories burned is 2,304 calories, equivalent to 0.6583lb(Pounds). i couldn't interpret into detail as Calories burned depends on several factors such as, age, weight, daily tasks, exercise, hormones and daily calories intake.
# 3. The average steps logged by users is  7,638 steps equivalent to 5.5km which is not adequate. As recommended by the 'Centers for Disease Control and Prevention CDC', an adult female has to aim at least 10,000 steps or 8km per day to benefit from general health, weight loss and fitness improvement.

# %% [markdown]
# # STEP 5: SHARE

# %% [markdown]
# In this step, visualizations will be created and our findings will be communicated based on our analysis.

# %% [markdown]
# #### 5.1 Data Visualisation and Findings

# %%
#import matplotlib package for  data visualization
import matplotlib.pyplot as plt 

#plotting histogram 
plt.style.use("default")
plt.figure(figsize=(6,4))  #Specify the size of the chart
plt.hist(df_activity.day_of_the_week, bins=7, width = 0.6, color = "blue", edgecolor = "black")

# adding annotationd and visuals
plt.xlabel("Day of the week")
plt.ylabel("Frequency")
plt.title("Number of times users logged in app over the week")
plt.grid(True)
plt.show()

# %% [markdown]
# ##### Frequency of usage over the week

# %% [markdown]
# The histogram above shows the frequency of the FitBit usage in terms of days of the week.
# 1. vividly, it is discovered from the above histogram that users prefer or remember to track their activity on the app during midweek from Tuesday to Friday
# 2. The frequency dropped on Friday and continue on weekends and Monday.

# %%
#plotting scatter plot
plt.style.use("default")
plt.figure(figsize=(8,6)) #it specifies the size of the chart
plt.scatter(df_activity.total_steps, df_activity.calories, alpha = 0.8, c = df_activity.calories, cmap = "Spectral")

#add annotations and visuals
median_calories = 2303
median_steps = 7637

plt.colorbar(orientation = "vertical")
plt.axvline(median_steps, color = "Blue", label = "Median steps")
plt.axhline(median_calories, color = "Red", label = "Median calories burned")

plt.xlabel("Steps taken")
plt.ylabel("Calories burned")
plt.title("Calories burned for every step taken")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ##### Calories burned for every step taken

# %% [markdown]
# From the scatter plot, we discovered that:
# 1. It is a positive correlation.
# 2. The intensity of calories burned increase when users are at the range of >0 to 15,000 steps with calories burn rate cooling down from 15,000 steps onwards.
# 3. Noted a few outliers which could be due to natural variation of data, errors in data collection(ie. human error or miscalculations).
#    - Zero steps with zero to minimal calories burned.
#    - 1 obsrvation of > 35,000 steps with < 3,000 calories burned.

# %%
#plotting scatter plot
plt.style.use("default")
plt.figure(figsize=(8,6)) #it specifies the size of the chart
plt.scatter(df_activity.total_hours, df_activity.calories, alpha = 0.8, c = df_activity.calories, cmap = "Spectral")

#add annotations and visuals
median_calories = 2303
median_hours = 20
median_sedentary = 991/60

plt.colorbar(orientation = "vertical")
plt.axvline(median_hours, color = "Blue", label = "Median hours")
plt.axvline(median_sedentary, color = "Purple", label = "Median sedentary")
plt.axhline(median_calories, color = "Red", label = "Median hours")

plt.xlabel("Hours logged")
plt.ylabel("Calories burned")
plt.title("Calories burned for every hour logged")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ##### Calories burned for every hour logged
# From the scatter plot, we discovered that;
# 1. it is a weak positive correlation whereby the increase of hours logged does not translateto more calories being burned. That is largely due to the average sedentary hours(purple line) plotted at the 16 to 17 hours range.
# 2. Noted a few outliers:
#     - The same zero value outliers
#     - An unusual red dot at the 24 hours with zero calorie burned which may due to the same reason as above.

# %%
#Calculating total of individual minutes column
very_active_mins = df_activity["very_active_mins"].sum()
fairly_active_mins = df_activity["fairly_active_mins"].sum()
lightly_active_mins = df_activity["lightly_active_mins"].sum()
sedentary_mins = df_activity["sedentary_mins"].sum()

#Visualizing then sum of individual minutes column usign Pie Chart
slices = [very_active_mins,fairly_active_mins,lightly_active_mins, sedentary_mins]
labels = ["Very active mins","Fairly active mins","Lightly active mins","Sedentary mins"]
colors = ["lightskyblue", "lightcoral", "darkorange", "yellowgreen"]
explode = [0,0,0,0.1]
plt.style.use("default")
plt.pie(slices, labels = labels, colors = colors, wedgeprops = {"edgecolor":"black"}, explode = explode, autopct = "%1.1f%%")
plt.title("Percentage of Activity in Minutes")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Percentage of Activity in Minutes
# From the above pie chart, the following are discovered:
# 1. The sedentary minutes takes the biggest slice at 81.3%, followed by the lightly active minutes with 15.8%, then very active minutes follows with 1.7% and lastly, Fairly active minutes with 1.1%.
# 2. This indicates that majority of the users are using the FitBit app to log daily activities such as daily commute, inactive movements or running errands.
# 3. As per the minor percentage of fairly active activity (1.1%) and very active activity (1.7%), the app is rarely being used to track fitness(ie running) which is highly discouraging, as FitBit app wa developed to encourage fitness.

# %% [markdown]
# # STEP 6: ACT

# %% [markdown]
# In this final step, our insights will be delivered and recommendations will be provided based on our analysis.

# %% [markdown]
# Here, we re-call our business questions and share with you our high-level business recommendations.

# %% [markdown]
# #### 1. What are the trends identified?
# - Users prefer to track their activities during the midweek(Tuesday to Friday) as compared to other days(Sunday to Monday).Perhaps because they spend more time outside on weekdays and stay in on weekends.
# - Majority of users (Sedentary 81.3%) are using the FitBit app to track sedentary activities and not using it for tracking their health habits.
# - There is a positive relationship between the total number of steps and the total number of burned calories
#
# #### 2. How could these trends apply to Bellabeat customers?
# - FitBit and Bellabeat develop products focused on women with their health, habit and fitness data, encouraging them to understand their current habits and make healthy decisions. These common trends surrounding health and fitness can very well be applied to Bellabeat customers.
#
# #### 3. How could these trends help influence Bellabeat marketing strategy
# - Bellabeat marketing team can encourage users by educating and equipping them with knowledge about fitness benefits.
# - Suggest different types of exercise (ie simple 10 minutes exercise on weekdays and a more intense exercise on weekends) and calories intake and burnt information on the Bellabeat app.
# - Prompt notification: On weekends, Bellabeat app can also prompt notification to notify and encourage users to exercise.
# - Dynamic Calorie Counter: The app could also provide the user with an elegantly designed, easy-to-use interface that displays the number of calories that are being burned throughout the day to improve motivation. The user could also have the option to set their customized daily calories goal and be able to follow their progress throughout the day.
# - Discounts on Other Bellabeat Wellness Products and Services: Another way to keep customers motivated is to offer special discounts on the different Bellabeat products, as well as their premium membership. This way, the users could become more inclined to get more active and purchase more products from the company.
